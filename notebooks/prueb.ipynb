# %%
import sys
import os

sys.path.append(os.path.abspath("../scripts"))

# %%
from pipeline import generar_features_para_prediccion

# %%
from pipeline import generar_features_para_prediccion  # o como hayas guardado esa función

# Coordenadas de prueba (una finca cafetera real)
x = -76.16196758044275  # lon
y = 7.023142287791029    # lat

df_final = generar_features_para_prediccion(x, y)

# Verifica el resultado
print(df_final.head())
print("Columnas:", df_final.columns)
print("Forma:", df_final.shape)
# Out:
# Respuesta completa de la API:
# {
#   "latitude": 6.9947276,
#   "longitude": -76.253174,
#   "generationtime_ms": 17.712116241455078,
#   "utc_offset_seconds": -18000,
#   "timezone": "America/Bogota",
#   "timezone_abbreviation": "GMT-5",
#   "elevation": 1121.0,
#   "daily_units": {
#     "time": "iso8601",
#     "temperature_2m_mean": "\u00b0C",
#     "precipitation_sum": "mm",
#     "relative_humidity_2m_mean": "%",
#     "et0_fao_evapotranspiration": "mm"
#   },
#   "daily": {
#     "time": [
#       "2025-06-05",
#       "2025-06-06",
#       "2025-06-07",
#       "2025-06-08",
#       "2025-06-09",
#       "2025-06-10",
#       "2025-06-11",
#       "2025-06-12",
#       "2025-06-13",
#       "2025-06-14",
#       "2025-06-15",
#       "2025-06-16",
#       "2025-06-17",
#       "2025-06-18",
#       "2025-06-19",
#       "2025-06-20",
#       "2025-06-21",
#       "2025-06-22",
#       "2025-06-23",
#       "2025-06-24",
#       "2025-06-25",
#       "2025-06-26",
# ...
